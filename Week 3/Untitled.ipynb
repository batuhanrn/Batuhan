# %%
import pandas as pd 

df_ispark = pd.read_excel('ispark-otoparklarna-ait-bilgiler.xlsx',sheet_name='ispark')
df_ispark.head()
Park Adı
# Out:
#    Park ID                     Park Adı  Lokasyon ID  Lokasyon Kodu  \
# 0      359            Atatürk Bulvarı 1          150              1
# 1      860  Bakırköy İstanbul Caddesi 1          384              2
# 2      861  Bakırköy İstanbul Caddesi 2          384              2
# 3      862  Bakırköy İstanbul Caddesi 3          384              2
# 4      867  Bakırköy İstanbul Caddesi 8          384              2
#
#                      Lokasyon Adı  Park Tipi ID Park Tipi  Park Kapasitesi  \
# 0          0001 Atatürk Bulvarı 1             2  YOL ÜSTÜ               18
# 1  0002 Bakırköy İstanbul Caddesi             2  YOL ÜSTÜ               30
# 2  0002 Bakırköy İstanbul Caddesi             2  YOL ÜSTÜ               30
# 3  0002 Bakırköy İstanbul Caddesi             2  YOL ÜSTÜ               70
# 4  0002 Bakırköy İstanbul Caddesi             2  YOL ÜSTÜ               40
#
#   Calışma Saatleri  Bölge ID            ...                 İlçe  \
# ...

# %%
df_ispark.Boylam
# Out:
# 0      28.953538
# 1      28.874742
# 2      28.875321
# 3      28.875957
# 4      28.878948
# 5      28.879684
# 6      29.010652
# 7      29.043497
# 8      29.043446
# 9      28.969039
# 10     28.969668
# 11     28.957580
# 12     28.958074
# 13           NaN
# 14     28.975309
# 15     28.970883
# 16     28.970279
# 17     28.969690
# 18     29.033346
# 19           NaN
# 20           NaN
# 21           NaN
# 22           NaN
# 23     28.894593
# 24           NaN
# 25           NaN
# 26           NaN
# 27     29.104514
# 28           NaN
# 29     29.188063
#          ...
# 701    28.794282
# 702    29.117302
# 703          NaN
# 704          NaN
# 705    28.907018
# 706    28.937135
# 707    29.320848
# 708          NaN
# 709          NaN
# 710    29.111852
# 711          NaN
# 712    29.255476
# 713    29.020938
# 714          NaN
# 715    29.050076
# 716    28.738209
# 717    28.990326
# 718    28.919668
# 719    28.919616
# 720          NaN
# 721    28.986863
# ...

# %%
import folium

for enlem,boylam in zip(df_ispark['Enlem'],df_ispark['Boylam']):
    world_map = folium.Map(location=[enlem,boylam], zoom_start=4)
world_map
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-a538d9846dc7> in <module>()
# ----> 1 import folium
#       2
#       3 for enlem,boylam in zip(df_ispark['Enlem'],df_ispark['Boylam']):
#       4     world_map = folium.Map(location=[enlem,boylam], zoom_start=4)
#       5 world_map
#
# ModuleNotFoundError: No module named 'folium'
